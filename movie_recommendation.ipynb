# %% [markdown]
# <a href="https://colab.research.google.com/github/301003bhavana/301003bhavana/blob/main/movie_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING THE DEPENDENCIES

# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# DATA COLLECTION AND PRE-PROCESSING

# %%
movies_data=pd.read_csv('/content/movies.csv')             #loading the data from the csv file to a pandas dataframe

# %%
movies_data.head()      #printing the first 5 rows of the data frame
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
# number of rows and columns in the data frame
movies_data.shape
# Out:
# (5009, 24)

# %%
#selecting the relevant features for recommendation
selected_features=['genres','keywords','tagline','cast','director']
print(selected_features)
# Out:
# ['genres', 'keywords', 'tagline', 'cast', 'director']

# %%
# replacing the null values with null string
for feature in selected_features:
  movies_data[feature]=movies_data[feature].fillna('')

# %%
#combining all the 5 selected features
combined_features=movies_data['genres']+' '+movies_data['keywords']+' '+movies_data['tagline']+' '+movies_data['cast']+' '+movies_data['director']

# %%
print(combined_features)
# Out:
# 0       Action Adventure Fantasy Science Fiction cultu...
# 1       Adventure Fantasy Action ocean drug abuse exot...
# 2       Action Adventure Crime spy based on novel secr...
# 3       Action Crime Drama Thriller dc comics crime fi...
# 4       Action Adventure Science Fiction based on nove...
#                               ...
# 5004    Action Crime Thriller united states\u2013mexic...
# 5005    Comedy Romance  A newlywed couple's honeymoon ...
# 5006    Comedy Drama Romance TV Movie date love at fir...
# 5007      A New Yorker in Shanghai Daniel Henney Eliza...
# 5008    Documentary obsession camcorder crush dream gi...
# Length: 5009, dtype: object

# %%
#converting the text data to feature vectors
vectorizer=TfidfVectorizer()

# %%
feature_vectors=vectorizer.fit_transform(combined_features)

# %%
print(feature_vectors)
# Out:
#   (0, 2432)	0.17109874407082
#   (0, 7755)	0.1128490533355917
#   (0, 13024)	0.19656054872823203
#   (0, 10229)	0.16170974915264116
#   (0, 8756)	0.22957586921041578
#   (0, 14608)	0.1528347287142878
#   (0, 16668)	0.200777593884698
#   (0, 14064)	0.20834283476975407
#   (0, 13319)	0.2201868742922369
#   (0, 17290)	0.2043414989573712
#   (0, 17007)	0.23552624406562966
#   (0, 13349)	0.15107015276619232
#   (0, 11503)	0.2654309543307533
#   (0, 11192)	0.09099678260685296
#   (0, 16998)	0.1284481127469341
#   (0, 15261)	0.07090441743505504
#   (0, 4945)	0.24280891431149512
#   (0, 14271)	0.2097935938293114
#   (0, 3225)	0.25219790922967394
#   (0, 16587)	0.1256288035810579
#   (0, 14378)	0.3353202480157101
#   (0, 5836)	0.1634554435815808
#   (0, 3065)	0.22229319896455033
#   (0, 3678)	0.21634282410933642
#   (0, 5437)	0.10267087684118094
#   :	:
#   (5007, 17266)	0.28927820763340395
#   (5007, 4835)	0.24791726335783
#   (5007, 403)	0.17563242835956222
# ...

# %% [markdown]
# COSINE SIMILARITY

# %%
#getting the similarity scores using using cosine similarity
similarity=cosine_similarity(feature_vectors)

# %%
print(similarity)
# Out:
# [[1.         0.07170094 0.0374877  ... 0.         0.         0.        ]
#  [0.07170094 1.         0.03226748 ... 0.03633077 0.         0.        ]
#  [0.0374877  0.03226748 1.         ... 0.         0.05347253 0.        ]
#  ...
#  [0.         0.03633077 0.         ... 1.         0.         0.02679399]
#  [0.         0.         0.05347253 ... 0.         1.         0.        ]
#  [0.         0.         0.         ... 0.02679399 0.         1.        ]]

# %%
print(similarity.shape)
# Out:
# (5009, 5009)

# %%
#getting the movie name from the user
try:
   movie_name=input('enter your favourite movie name: ')
except KeyboardInterrupt:
    print('interrupted by user')
# Out:
# interrupted by user

# %%
#creating a list with all the movie names given in the  dataset
list_of_all_titles=movies_data['title'].tolist()
print(list_of_all_titles)
# Out:
# ['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre', 'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'Superman Returns', 'Quantum of Solace', "Pirates of the Caribbean: Dead Man's Chest", 'The Lone Ranger', 'Man of Steel', 'The Chronicles of Narnia: Prince Caspian', 'The Avengers', 'Pirates of the Caribbean: On Stranger Tides', 'Men in Black 3', 'The Hobbit: The Battle of the Five Armies', 'The Amazing Spider-Man', 'Robin Hood', 'The Hobbit: The Desolation of Smaug', 'The Golden Compass', 'King Kong', 'Titanic', 'Captain America: Civil War', 'Battleship', 'Jurassic World', 'Skyfall', 'Spider-Man 2', 'Iron Man 3', 'Alice in Wonderland', 'X-Men: The Last Stand', 'Monsters University', 'Transformers: Revenge of the Fallen', 'Transformers: Age of Extinction', 'Oz: The Great and Powerful', 'The Amazing Spider-Man 2', 'TRON: Legacy', 'Cars 2', 'Green La
# ...

# %%
# finding the close match for the movie name given by the user
movie_name="iron man"
find_close_match=difflib.get_close_matches(movie_name,list_of_all_titles)
print(find_close_match)
# Out:
# ['Iron Man', 'Iron Man 3', 'Iron Man 2']

# %%
close_match=find_close_match[0]
print(close_match)
# Out:
# Iron Man

# %%
#find the index of the movie with title
index_of_the_movie=movies_data[movies_data.title==close_match]['index'].values[0]
print(index_of_the_movie)
# Out:
# 68

# %%
#getting a list of similar movies
similarity_score=list(enumerate(similarity[index_of_the_movie]))
print(similarity_score)
# Out:
# [(0, 0.03263172554005118), (1, 0.053821591590807405), (2, 0.013218836018655186), (3, 0.006230512504983415), (4, 0.03175582552507858), (5, 0.01330091393026455), (6, 0.07654538207597572), (7, 0.23750507603675092), (8, 0.007549582311434475), (9, 0.07524801058600136), (10, 0.07456028715436987), (11, 0.011433349385656093), (12, 0.013265467028636718), (13, 0.01189161107737802), (14, 0.09540414782925268), (15, 0.0069593082204624365), (16, 0.22466636592320272), (17, 0.01258622646640529), (18, 0.04076722099844143), (19, 0.07707571568716479), (20, 0.07810467081322105), (21, 0.010834315727083502), (22, 0.00663611885256021), (23, 0.006317957749416927), (24, 0.012100528640245231), (25, 0.0), (26, 0.2129536649634259), (27, 0.029551682918244896), (28, 0.05993093961489679), (29, 0.013469376609713406), (30, 0.07903433070591047), (31, 0.3140030728902902), (32, 0.02865358811999127), (33, 0.12942110993811476), (34, 0.0), (35, 0.03429694870466212), (36, 0.03089094696540747), (37, 0.0076820177681752285), 
# ...

# %%
len(similarity_score)
# Out:
# 5009

# %%
#sorting the movies based on their similarity score
sorted_similar_movies=sorted(similarity_score,key=lambda x:x[1],reverse=True)
print(sorted_similar_movies)
# Out:
# [(68, 1.0), (79, 0.4087973411264318), (31, 0.3140030728902902), (7, 0.23750507603675092), (16, 0.22466636592320272), (26, 0.2129536649634259), (85, 0.20344818686224328), (276, 0.19334120876356192), (717, 0.16614028521115798), (3829, 0.16162350386309005), (64, 0.15099195052978887), (101, 0.14724824345993523), (409, 0.14724824345993523), (268, 0.14514334106244547), (4607, 0.1426714645997541), (195, 0.14202502738334763), (46, 0.1401105512798077), (263, 0.1352054156279214), (1946, 0.13447188619259492), (94, 0.13349771407062858), (994, 0.13112161729599164), (220, 0.130981500973), (225, 0.13022265884109138), (33, 0.12942110993811476), (2693, 0.12440510774364547), (989, 0.1226959344026017), (232, 0.11927923731721778), (867, 0.11651975337793556), (813, 0.11462041419953156), (2648, 0.11458005133662819), (2857, 0.11436601669694385), (353, 0.11224523169808774), (559, 0.11224523169808774), (38, 0.11028854781868137), (1759, 0.10926067354587096), (1657, 0.10849329304260703), (216, 0.10617000238228
# ...

# %%
#print the name of the similar movies based on the index
print('movies suggested for you: \n')
i=1
for movie in sorted_similar_movies:
  index=int(movie[0])
  title_from_index=movies_data[movies_data.index==index]['title'].values[0]
  if(i<30):
    print(i,'.',title_from_index)
    i+=1
# Out:
# movies suggested for you:
#
# 1 . Iron Man
# 2 . Iron Man 2
# 3 . Iron Man 3
# 4 . Avengers: Age of Ultron
# 5 . The Avengers
# 6 . Captain America: Civil War
# 7 . Captain America: The Winter Soldier
# 8 . Ant-Man
# 9 . X-Men
# 10 . Made
# 11 . X-Men: Apocalypse
# 12 . X2
# 13 . X2
# 14 . The Incredible Hulk
# 15 . The Helix... Loaded
# 16 . X-Men: First Class
# 17 . X-Men: Days of Future Past
# 18 . Captain America: The First Avenger
# 19 . Kick-Ass 2
# 20 . Guardians of the Galaxy
# 21 . Deadpool
# 22 . Thor: The Dark World
# 23 . G-Force
# 24 . X-Men: The Last Stand
# 25 . Duets
# 26 . Mortdecai
# 27 . The Last Airbender
# 28 . Zathura: A Space Adventure
# 29 . Sky Captain and the World of Tomorrow

# %% [markdown]
# MOVIE FRECOMMENDATION SYSTEM

# %%
try:
  movie_name=input('enter your favourite movie name: ')
except:
  print('keyboardInterrupt caught.continuing exceution')
list_of_all_titles=movies_data['title'].tolist()
find_close_match=difflib.get_close_matches(movie_name,list_of_all_titles)
close_match=find_close_match[0]
index_of_the_movie=movies_data[movies_data.title==close_match]['index'].values[0]
similarity_score=list(enumerate(similarity[index_of_the_movie]))
sorted_similar_movies=sorted(similarity_score,key=lambda x:x[1],reverse=True)
print('movies suggested for you: \n')
i=1
for movie in sorted_similar_movies:
  index=int(movie[0])
  title_from_index=movies_data[movies_data.index==index]['title'].values[0]
  if(i<30):
    print(i,'.',title_from_index)
    i+=1
# Out:
# enter your favourite movie name: bat man
# movies suggested for you:
#
# 1 . Lucy
# 2 . Her
# 3 . Sympathy for Lady Vengeance
# 4 . Firestarter
# 5 . Coal Miner's Daughter
# 6 . Transcendence
# 7 . Transcendence
# 8 . Oldboy
# 9 . The Bucket List
# 10 . The Helix... Loaded
# 11 . The Fifth Element
# 12 . The Fifth Element
# 13 . Terminator Salvation
# 14 . The Terminator
# 15 . Terminator Genisys
# 16 . Stealth
# 17 . Layer Cake
# 18 . The Messenger: The Story of Joan of Arc
# 19 . Terminator 3: Rise of the Machines
# 20 . The Matrix
# 21 . I, Robot
# 22 . I, Robot
# 23 . The Island
# 24 . The Island
# 25 . TRON: Legacy
# 26 . The Matrix Revolutions
# 27 . The Matrix Reloaded
# 28 . Star Trek: The Motion Picture
# 29 . 2001: A Space Odyssey
